# %% [markdown]
# <a href="https://colab.research.google.com/github/maheshsk78/ESG_TextMining/blob/main/financial_services.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount("/content/drive")

# %%
# !ls /content/drive/'Shared drives'/ELP_Hyrdus_GroupWork/'WRDS - 10K'/
# Out:
# consumer_financials.xlsx     financial_services.xlsx
# diversified_financials.xlsx  WRDS_SEC_Readability_and_Sentiment_Manual.pdf
# financial_services.csv

# %%
import pandas as pd
from matplotlib import pyplot
from scipy import stats

# %%
df_financial = pd.read_excel("/content/drive/Shared drives/ELP_Hyrdus_GroupWork/WRDS - 10K/financial_services.xlsx")

# %%
#df_diversified.head()
df_diversified.set_index(df_diversified.F_date, inplace=True)
df_diversified.head()

# %%
data_rev=df_diversified[(df_diversified.TICKERH == 'CBOE') | (df_diversified.TICKERH == 'CME') | (df_diversified.TICKERH == 'MCO') 
                | (df_diversified.TICKERH == 'MORN') |(df_diversified.TICKERH == 'NDAQ') | (df_diversified.TICKERH == 'SPGI') 
                | (df_diversified.TICKERH == 'ALLY') | (df_diversified.TICKERH == 'AXP') |(df_diversified.TICKERH == 'COF')
                | (df_diversified.TICKERH == 'DFS') | (df_diversified.TICKERH == 'GDOT') |(df_diversified.TICKERH == 'PRA')  ]

data_rev.head(1)
# Out:
#                 CIK     FDATE  ... FinTerms_Positive_count  TICKERH
# F_date                         ...
# 2010-02-26  1156375  20100226  ...                     536      CME
#
# [1 rows x 45 columns]

# %%
import seaborn as sns
sns.pairplot(x_vars=["F_year"], y_vars=["ARI"], data=data_rev, hue="TICKERH", size=5)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/axisgrid.py:2071: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
groups = data_rev.groupby('TICKERH')

# Plot
fig, ax = plt.subplots()
ax.margins(0.05) # Optional, just adds 5% padding to the autoscaling
for name, group in groups:
    ax.plot(group.F_year, group.ARI, marker='o', linestyle='', ms=3, label=name)
ax.legend()
plt.title("Automated Readability Index")

plt.show()

# %%
sns.pairplot(vars=["FinTerms_Negative","FinTerms_Positive","FinTerms_Litigious","FinTerms_Uncertainty"],data=data_rev hue="TICKERH", size=5)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/axisgrid.py:2071: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
